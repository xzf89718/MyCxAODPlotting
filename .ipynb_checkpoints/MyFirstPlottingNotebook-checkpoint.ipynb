# %% [markdown]
# # This is my first plotting script for CxAODReaderbbtt output

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/02

# %%
# Select variable
def SelectVariable(list_of_hist, variable):
    """
    input: list of histogram, variable
    output: list contains all histo with variable
    """
    list_return = []
    for _hist in list_of_hist:

        _a = _hist.split('_')
        # print(_a)
        if _a[-1:][0] == variable:
            list_return.append(_hist)

    return list_return


def splitRegion(list_of_name):
    """
    input :such as [a,b,c,d,e,f]
    output: b_c_d_e
    """

    return list_of_name[1]+'_'+list_of_name[2]+'_'+list_of_name[3]+'_'+list_of_name[4]

# Get All histograms name in Preselection


def GetAllKeysInPreselection(tPre):
    """
     input: TPreselection
     return: All TH1F in TPreselection as a list

    """
    olist = []
    for key in tPre.GetListOfKeys():
        if key.GetName() == 'Systematics':
            continue
        olist.append(key.GetName())
    return olist

# %%
# path for Hist-OUTPUT
dirHistOUTPUT = '/home/xuzifeng/HistxAOD/submitDir/hist-OUTPUT.root'
dir_save_figure='/home/xuzifeng/HistxAOD/submitDir/figure/'

# Select histograms we need!
region_tag = '2tag2pjet_0ptv_LL_OS'

# Get Preselection
file = ROOT.TFile(dirHistOUTPUT)
tPreselection = file.Get('Preselection')

# %%
# Get all keys of histograms and save them in a list!

# Get All Keys!
ALLHIST=GetAllKeysInPreselection(tPreselection)
print(ALLHIST)
# Out:
# ['data_2tag2pjet_0ptv_LL_SS_mMMC', 'data_2tag2pjet_0ptv_LL_SS_dRBB', 'data_2tag2pjet_0ptv_LL_SS_dRTauTau', 'data_2tag2pjet_0ptv_LL_SS_Tau1Eta', 'data_2tag2pjet_0ptv_LL_SS_Tau0Eta', 'data_2tag2pjet_0ptv_LL_SS_Tau1Pt', 'data_2tag2pjet_0ptv_LL_SS_pTB1', 'data_2tag2pjet_0ptv_LL_SS_pTB0', 'data_2tag2pjet_0ptv_LL_SS_Jet0Pt', 'data_2tag2pjet_0ptv_LL_SS_Yield', 'data_1tag2pjet_0ptv_LL_OS_pTB1', 'Fake_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'Fake_1tag2pjet_0ptv_LL_SS_mHH', 'Fake_1tag2pjet_0ptv_LL_SS_pTB0', 'Fake_1tag2pjet_0ptv_LL_SS_Tau0Eta', 'Fake_1tag2pjet_0ptv_LL_SS_mMMC', 'Fake_1tag2pjet_0ptv_LL_SS_mJJVBF', 'Fake_1tag2pjet_0ptv_LL_SS_Tau1Eta', 'Fake_1tag2pjet_0ptv_LL_SS_Tau1Pt', 'Fake_1tag2pjet_0ptv_LL_SS_dRTauTau', 'data_1tag2pjet_0ptv_LL_OS_Tau1Pt', 'Fake_1tag2pjet_0ptv_LL_SS_Tau0Pt', 'data_1tag2pjet_0ptv_LL_OS_dEtaVBF', 'data_1tag2pjet_0ptv_LL_SS_dEtaVBF', 'data_2tag2pjet_0ptv_LL_SS_nJets', 'Fake_1tag2pjet_0ptv_LL_SS_Yield', 'data_1tag2pjet_0ptv_LL_SS_dRBB', 'Fake_2tag2pjet_0ptv_LL_SS_mJJVBF', 'Fake_1tag2pjet_0ptv_LL_OS_mBB', 'Fake_1tag2pjet_0ptv_LL_OS_pTB1', 'Fake_1tag2pjet_0ptv_LL_OS_Yield', 'Fake_1tag2pjet_0ptv_LL_OS_pTB0', 'Fake_1tag2pjet_0ptv_LL_OS_mMMC', 'Fake_1tag2pjet_0ptv_LL_OS_Tau0Eta', 'Fake_1tag2pjet_0ptv_LL_OS_Tau1Eta', 'Fake_1tag2pjet_0ptv_LL_OS_mJJVBF', 'Fake_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'Fake_2tag2pjet_0ptv_LL_SS_Jet0Pt', 'Fake_1tag2pjet_0ptv_LL_OS_Tau1Pt', 'Fake_1tag2pjet_0ptv_LL_SS_dRBB', 'Fake_1tag2pjet_0ptv_LL_SS_dEtaVBF', 'Fake_1tag2pjet_0ptv_LL_OS_dRBB', 'data_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'Fake_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'data_2tag2pjet_0ptv_LL_SS_MET', 'Fake_1tag2pjet_0ptv_LL_OS_Jet1Pt', 'Fake_2tag2pjet_0ptv_LL_OS_Yield', 'data_1tag2pjet_0ptv_LL_SS_mBB', 'data_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'Fake_1tag2pjet_0ptv_LL_OS_dRTauTau', 'data_2tag2pjet_0ptv_LL_SS_mJJVBF', 'Fake_1tag2pjet_0ptv_LL_OS_Tau0Pt', 'Fake_1tag2pjet_0ptv_LL_SS_nJets', 'Fake_1tag2pjet_0ptv_LL_SS_MET', 'Fake_2tag2pjet_0ptv_LL_SS_Tau0Eta', 'data_1tag2pjet_0ptv_LL_SS_nJets', 'Fake_2tag2pjet_0ptv_LL_SS_mMMC', 'Fake_1tag2pjet_0ptv_LL_OS_dEtaVBF', 'data_1tag2pjet_0ptv_LL_SS_mHH', 'Fake_2tag2pjet_0ptv_LL_SS_mBB', 'Fake_1tag2pjet_0ptv_LL_SS_mBB', 'Fake_1tag2pjet_0ptv_LL_OS_Jet0Pt', 'Fake_1tag2pjet_0ptv_LL_SS_pTB1', 'Fake_1tag2pjet_0ptv_LL_OS_nJets', 'Fake_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'Fake_2tag2pjet_0ptv_LL_OS_pTB0', 'Fake_2tag2pjet_0ptv_LL_OS_mJJVBF', 'data_1tag2pjet_0ptv_LL_SS_Tau1Eta', 'data_1tag2pjet_0ptv_LL_OS_Yield', 'data_1tag2pjet_0ptv_LL_OS_MET', 'data_1tag2pjet_0ptv_LL_OS_nJets', 'data_1tag2pjet_0ptv_LL_OS_Jet0Pt', 'data_1tag2pjet_0ptv_LL_OS_pTB0', 'data_1tag2pjet_0ptv_LL_OS_Tau0Pt', 'data_1tag2pjet_0ptv_LL_OS_Tau0Eta', 'data_1tag2pjet_0ptv_LL_OS_Tau1Eta', 'data_1tag2pjet_0ptv_LL_OS_mJJVBF', 'data_1tag2pjet_0ptv_LL_OS_dRBB', 'data_1tag2pjet_0ptv_LL_OS_mMMC', 'data_1tag2pjet_0ptv_LL_OS_mBB', 'data_1tag2pjet_0ptv_LL_OS_mHH', 'data_1tag2pjet_0ptv_LL_SS_Yield', 'data_1tag2pjet_0ptv_LL_SS_MET', 'data_1tag2pjet_0ptv_LL_SS_Jet0Pt', 'data_1tag2pjet_0ptv_LL_SS_pTB1', 'data_1tag2pjet_0ptv_LL_SS_Tau0Pt', 'data_1tag2pjet_0ptv_LL_SS_mJJVBF', 'data_1tag2pjet_0ptv_LL_SS_dRTauTau', 'data_2tag2pjet_0ptv_LL_OS_Yield', 'data_2tag2pjet_0ptv_LL_OS_MET', 'data_2tag2pjet_0ptv_LL_OS_nJets', 'data_2tag2pjet_0ptv_LL_OS_pTB0', 'data_2tag2pjet_0ptv_LL_OS_pTB1', 'data_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'data_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'data_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'data_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'data_2tag2pjet_0ptv_LL_OS_mJJVBF', 'data_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'data_2tag2pjet_0ptv_LL_OS_dRTauTau', 'data_2tag2pjet_0ptv_LL_OS_dRBB', 'data_2tag2pjet_0ptv_LL_OS_mBB', 'Fake_2tag2pjet_0ptv_LL_OS_MET', 'data_2tag2pjet_0ptv_LL_OS_mHH', 'Fake_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'Fake_2tag2pjet_0ptv_LL_SS_Yield', 'Fake_2tag2pjet_0ptv_LL_SS_MET', 'Fake_2tag2pjet_0ptv_LL_SS_nJets', 'Fake_2tag2pjet_0ptv_LL_SS_Jet1Pt', 'Fake_1tag2pjet_0ptv_LL_SS_Jet1Pt', 'Fake_2tag2pjet_0ptv_LL_SS_pTB0', 'Fake_2tag2pjet_0ptv_LL_OS_nJets', 'Fake_2tag2pjet_0ptv_LL_SS_pTB1', 'data_1tag2pjet_0pt ...

# %%
# Get All Keys and sve them in table
dic_hist = {'Process': [], 'Region': [], 'Variable': []}

# %%
# Just GetKeys and save them in a dictionary

for h_name in ALLHIST:
    h_name = h_name.split('_')
    process_name = h_name[0]
    region_name = splitRegion(h_name)
    variable_name = h_name[-1]

    if process_name not in dic_hist['Process']:
        dic_hist['Process'].append(process_name)
    if region_name not in dic_hist['Region']:
        dic_hist['Region'].append(region_name)
    if variable_name not in dic_hist['Variable']:
        dic_hist['Variable'].append(variable_name)
print(dic_hist)
# Out:
# {'Process': ['data', 'Fake', 'ggFHtautau', 'VBFHtautau', 'WHtautau', 'hhttbb', 'hhttbbFTapprox', 'stops', 'stopt', 'stopWt', 'ttbar', 'ttbarSFTF', 'ttbarSFFF', 'ttbarSFFT', 'ttbarAF2', 'ttbarAF2FT', 'ttbarAF2TF', 'ttbarAF2FF', 'ttbarAMCP8', 'ttbarAMCP8FT', 'ttbarAMCP8TF', 'ttbarAMCP8FF', 'ttbarPP8RadHiFF', 'ttbarPP8RadHiFT', 'ttbarPP8RadHiTF', 'ttbarPP8RadHi', 'ttbarPH7', 'ttbarPH7TF', 'ttbarPH7FT', 'ttbarPH7FF', 'WHbb', 'ZHbb', 'W', 'Wtt', 'WW', 'WZ', 'Hhhbbtautau1000', 'Hhhbbtautau1100', 'Hhhbbtautau1200', 'Hhhbbtautau1400', 'Hhhbbtautau1600', 'Hhhbbtautau1800', 'Hhhbbtautau2000', 'Hhhbbtautau2500', 'Hhhbbtautau251', 'Hhhbbtautau260', 'Hhhbbtautau280', 'Hhhbbtautau3000', 'Hhhbbtautau300', 'Hhhbbtautau325', 'Hhhbbtautau350', 'Hhhbbtautau400', 'Hhhbbtautau450', 'Hhhbbtautau500', 'Hhhbbtautau550', 'Hhhbbtautau600', 'Hhhbbtautau700', 'Hhhbbtautau800', 'Hhhbbtautau900', 'Zbl', 'Zbb', 'Zbc', 'Zcl', 'Zl', 'Zttcc', 'Zttl', 'Zttbc', 'Zttbb', 'Zttbl', 'Zttcl', 'ZZ'], 'Region': ['2tag2pjet_0ptv_LL_SS', '1tag2pjet_0ptv_LL_OS', '2tag2pjet_0ptv_LL_OS', '1tag2pjet_0ptv_LL_SS'], 'Variable': ['mMMC', 'dRBB', 'dRTauTau', 'Tau1Eta', 'Tau0Eta', 'Tau1Pt', 'pTB1', 'pTB0', 'Jet0Pt', 'Yield', 'mHH', 'mJJVBF', 'Tau0Pt', 'dEtaVBF', 'nJets', 'mBB', 'Jet1Pt', 'MET']}

# %%
# Now stack all histogram needed and draw

# Remember check if the histogram we generate in the ALLHIST
# Generate our histogramlist
data_list = []
fake_list = []
process_list = []

# %%
# Fill process_list
for _process in dic_hist['Process']:
    if _process == 'data':
        continue
    if _process == 'Fake':
        continue
    for _region in dic_hist['Region']:
        if _region == region_tag:
            for _variable in dic_hist['Variable']:
                a = _process + '_'+_region+'_'+_variable
                if a in ALLHIST:
                    process_list.append(a)
print(process_list)
# Out:
# ['ggFHtautau_2tag2pjet_0ptv_LL_OS_mMMC', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_dRBB', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_dRTauTau', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_pTB1', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_pTB0', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Yield', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_mHH', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_mJJVBF', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_nJets', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_mBB', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'ggFHtautau_2tag2pjet_0ptv_LL_OS_MET', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_mMMC', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_dRBB', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_dRTauTau', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_pTB1', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_pTB0', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Yield', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_mHH', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_mJJVBF', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_nJets', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_mBB', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'VBFHtautau_2tag2pjet_0ptv_LL_OS_MET', 'WHtautau_2tag2pjet_0ptv_LL_OS_mMMC', 'WHtautau_2tag2pjet_0ptv_LL_OS_dRBB', 'WHtautau_2tag2pjet_0ptv_LL_OS_dRTauTau', 'WHtautau_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'WHtautau_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'WHtautau_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'WHtautau_2tag2pjet_0ptv_LL_OS_pTB1', 'WHtautau_2tag2pjet_0ptv_LL_OS_pTB0', 'WHtautau_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'WHtautau_2tag2pjet_0ptv_LL_OS_Yield', 'WHtautau_2tag2pjet_0ptv_LL_OS_mHH', 'WHtautau_2tag2pjet_0ptv_LL_OS_mJJVBF', 'WHtautau_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'WHtautau_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'WHtautau_2tag2pjet_0ptv_LL_OS_nJets', 'WHtautau_2tag2pjet_0ptv_LL_OS_mBB', 'WHtautau_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'WHtautau_2tag2pjet_0ptv_LL_OS_MET', 'hhttbb_2tag2pjet_0ptv_LL_OS_mMMC', 'hhttbb_2tag2pjet_0ptv_LL_OS_dRBB', 'hhttbb_2tag2pjet_0ptv_LL_OS_dRTauTau', 'hhttbb_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'hhttbb_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'hhttbb_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'hhttbb_2tag2pjet_0ptv_LL_OS_pTB1', 'hhttbb_2tag2pjet_0ptv_LL_OS_pTB0', 'hhttbb_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'hhttbb_2tag2pjet_0ptv_LL_OS_Yield', 'hhttbb_2tag2pjet_0ptv_LL_OS_mHH', 'hhttbb_2tag2pjet_0ptv_LL_OS_mJJVBF', 'hhttbb_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'hhttbb_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'hhttbb_2tag2pjet_0ptv_LL_OS_nJets', 'hhttbb_2tag2pjet_0ptv_LL_OS_mBB', 'hhttbb_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'hhttbb_2tag2pjet_0ptv_LL_OS_MET', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_mMMC', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_dRBB', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_dRTauTau', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_pTB1', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_pTB0', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Yield', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_mHH', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_mJJVBF', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_nJets', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_mBB', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'hhttbbFTapprox_2tag2pjet_0ptv_LL_OS_MET', 'stops_2tag2pjet_0ptv_LL_OS_mMMC', 'stops_2tag2pjet_0ptv_LL_OS_dRBB', 'stops_2tag2pjet_0ptv_LL_OS_dRTauTau', 'stops_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'stops_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'stops_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'stops_2tag2pjet_0ptv_LL_OS_pTB1', 'stops_2tag2pjet_0ptv_LL_OS_pTB0', 'stops_2tag2pjet_0ptv_LL_OS_Jet0P ...

# %%
# Fill fake_list
for _process in dic_hist['Process']:
    if not(_process == 'Fake'):
        continue
    for _region in dic_hist['Region']:
        if _region == region_tag:
            for _variable in dic_hist['Variable']:
                a = _process + '_'+_region+'_'+_variable
                if a in ALLHIST:
                    fake_list.append(a)
print(fake_list)
# Out:
# ['Fake_2tag2pjet_0ptv_LL_OS_mMMC', 'Fake_2tag2pjet_0ptv_LL_OS_dRBB', 'Fake_2tag2pjet_0ptv_LL_OS_dRTauTau', 'Fake_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'Fake_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'Fake_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'Fake_2tag2pjet_0ptv_LL_OS_pTB1', 'Fake_2tag2pjet_0ptv_LL_OS_pTB0', 'Fake_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'Fake_2tag2pjet_0ptv_LL_OS_Yield', 'Fake_2tag2pjet_0ptv_LL_OS_mHH', 'Fake_2tag2pjet_0ptv_LL_OS_mJJVBF', 'Fake_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'Fake_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'Fake_2tag2pjet_0ptv_LL_OS_nJets', 'Fake_2tag2pjet_0ptv_LL_OS_mBB', 'Fake_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'Fake_2tag2pjet_0ptv_LL_OS_MET']

# %%
# Fill data_list
for _process in dic_hist['Process']:
    if not(_process == 'data'):
        continue
    for _region in dic_hist['Region']:
        if _region == region_tag:
            for _variable in dic_hist['Variable']:
                a = _process + '_'+_region+'_'+_variable
                if a in ALLHIST:
                    data_list.append(a)
print(data_list)
# Out:
# ['data_2tag2pjet_0ptv_LL_OS_mMMC', 'data_2tag2pjet_0ptv_LL_OS_dRBB', 'data_2tag2pjet_0ptv_LL_OS_dRTauTau', 'data_2tag2pjet_0ptv_LL_OS_Tau1Eta', 'data_2tag2pjet_0ptv_LL_OS_Tau0Eta', 'data_2tag2pjet_0ptv_LL_OS_Tau1Pt', 'data_2tag2pjet_0ptv_LL_OS_pTB1', 'data_2tag2pjet_0ptv_LL_OS_pTB0', 'data_2tag2pjet_0ptv_LL_OS_Jet0Pt', 'data_2tag2pjet_0ptv_LL_OS_Yield', 'data_2tag2pjet_0ptv_LL_OS_mHH', 'data_2tag2pjet_0ptv_LL_OS_mJJVBF', 'data_2tag2pjet_0ptv_LL_OS_Tau0Pt', 'data_2tag2pjet_0ptv_LL_OS_dEtaVBF', 'data_2tag2pjet_0ptv_LL_OS_nJets', 'data_2tag2pjet_0ptv_LL_OS_mBB', 'data_2tag2pjet_0ptv_LL_OS_Jet1Pt', 'data_2tag2pjet_0ptv_LL_OS_MET']

# %%
# Create histogram
hs_1 = ROOT.THStack('hs', 'test stacked histograms')
canvas_1 = ROOT.TCanvas()

# Get All and Fill

for _name_data in data_list:
    t_hist=tPreselection.Get(_name_data)
    t_hist.SetFillColor(ROOT.kRed)
    hs_1.Add(t_hist)

hs_1.Draw()
canvas_1.Update()
canvas_1.Draw()
hs_1.Clear()
# Out:
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_dRBB can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_dRBB.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_dRTauTau can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_dRTauTau.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_pTB0 can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_pTB0.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_Jet0Pt can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_Jet0Pt.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <Merge>: Cannot merge histograms - limits are inconsistent:
#  first: data_2tag2pjet_0ptv_LL_OS_Yield (1, 0.000000, 1.000000), second: data_2tag2pjet_0ptv_LL_OS_Jet0Pt (244, -10.000000, 600.000000)
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_mJJVBF can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_mHH.
# Info in <TH1F::Add>: Attempt to add histograms with different axis limits - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_Tau0Pt can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_Tau0Pt.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_mBB can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_mBB.
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Info in <TH1F::Add>: Attempt to add histograms with different axis limits - trying to use TH1::Merge
# Error in <TH1Merger::DifferentAxesMerge>: Cannot merge histograms - the histograms data_2tag2pjet_0ptv_LL_OS_MET can extend the X axis or have different limits and underflows/overflows are present in the histogram data_2tag2pjet_0ptv_LL_OS_MET.

# %%
# Create histogram
hs_2 = ROOT.THStack('hs_2', 'test stacked histograms')
canvas_2 = ROOT.TCanvas()

# %%
# Create All figure in different variable


# print(process_list)
# print(SelectVariable(process_list, 'mBB'))
for _variable in dic_hist['Variable']:

    # Collecting histogram with differenct variable
    hist_data = SelectVariable(data_list, _variable)
    hist_process = SelectVariable(process_list, _variable)
    hist_fake = SelectVariable(fake_list, _variable)

    for _hist in hist_process:
        _histogram=tPreselection.Get(_hist)
        hs_2.Add(_histogram)
    for _hist in hist_fake:
        _histogram=tPreselection.Get(_hist)
        hs_2.Add(_histogram)
    hs_2.Draw()
    canvas_2.Update()
    canvas_2.SaveAs(_variable+'.png')
    hs_2.Clear()
